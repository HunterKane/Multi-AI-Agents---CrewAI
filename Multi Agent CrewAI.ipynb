# %% [markdown]
# # Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# --------

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# -------

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# ### Comprehensive Task Breakdown for Website Project
#
# **Overview:**
# The goal is to create a professional and responsive website for a small business that effectively represents the brand, showcases services, promotes engagement, and optimizes user experience across devices.
#
# ---
#
# #### 1. Task Breakdown
#
# | Task                          | Description                                                                                                                 | Assigned To         | Duration              | Start Date   | End Date     | Dependencies                            | Deliverables                        |
# |-------------------------------|-----------------------------------------------------------------------------------------------------------------------------|---------------------|----------------------|--------------|--------------|------------------------------------------|-------------------------------------|
# | 1. Project Kick-off           | Initiate the project, set meetings, discuss project goals, and confirm the team structure.                                 | John Doe            | 1 day                | 09/01/2023   | 09/01/2023   | None                                     | Project Charter                     |
# | 2. Requirement Gathering       | Collect detailed requirements and expectations from stakeholders including brand guidelines, content, and functionalities. | John Doe, Jane Doe  | 3 days               | 09/02/2023   | 09/04/2023   | Task 1                                   | Requirements Document               |
# | 3. Create Wireframes          | Develop wireframes for key pages to visualize layout before design.                                                       | Bob Smith            | 5 days               | 09/05/2023   | 09/09/2023   | Task 2                                   | Wireframes                          |
# | 4. Responsive Design           | Create a responsive design ensuring compatibility with desktop and mobile devices.                                         | Bob Smith            | 7 days               | 09/10/2023   | 09/16/2023   | Task 3                                   | Design Mockups                      |
# | 5. UI Development             | Develop a modern user interface with a visually appealing and clean design as per approved mockups.                       | Jane Doe            | 10 days              | 09/17/2023   | 09/26/2023   | Task 4                                   | UI Components                       |
# | 6. Navigation System          | Create and implement a user-friendly navigation system with an intuitive menu structure.                                  | Jane Doe            | 5 days               | 09/27/2023   | 10/01/2023   | Task 5                                   | Navigation Menu                     |
# | 7. "About Us" Page           | Develop an "About Us" page that outlines the company's history and values.                                                 | Jane Doe            | 3 days               | 10/02/2023   | 10/04/2023   | Task 6                                   | About Us Page                       |
# | 8. "Services" Page            | Design and develop a "Services" page that showcases business offerings with descriptions.                                  | Jane Doe            | 4 days               | 10/05/2023   | 10/08/2023   | Task 7                                   | Services Page                       |
# | 9. "Contact Us" Page          | Create a "Contact Us" page including a form and integrated map for communication.                                         | Jane Doe            | 4 days               | 10/09/2023   | 10/12/2023   | Task 8                                   | Contact Us Page                     |
# | 10. Blog Section              | Implement a blog section for sharing industry news and company updates.                                                    | Jane Doe            | 6 days               | 10/13/2023   | 10/18/2023   | Task 9                                   | Blog Section                        |
# | 11. SEO Optimization          | Optimize the website for search engines to ensure fast loading times and better visibility.                                 | Jane Doe            | 4 days               | 10/19/2023   | 10/22/2023   | Tasks 8, 9, 10                          | SEO Audit Report                   |
# | 12. Social Media Integration   | Integrate social media links and sharing functionalities across the site.                                                  | Jane Doe            | 3 days               | 10/23/2023   | 10/25/2023   | Task 11                                  | Social Media Features               |
# | 13. Testimonials Section      | Design and implement a testimonials section to showcase customer feedback.                                                  | Bob Smith            | 3 days               | 10/26/2023   | 10/28/2023   | Task 12                                  | Testimonials Section                |
# | 14. Quality Assurance (QA)    | Conduct QA testing on all website functionalities and ensure everything works seamlessly across devices.                    | Alice Johnson, Tom Brown | 6 days           | 10/29/2023   | 11/03/2023   | All previous tasks                      | QA Report                          |
# | 15. Final Adjustments         | Make any necessary adjustments based on QA feedback.                                                                         | Jane Doe            | 3 days               | 11/04/2023   | 11/06/2023   | Task 14                                  | Updated Website                     |
# | 16. Project Closure           | Review project outcomes, evaluate project performance, and obtain final stakeholder approval.                                | John Doe            | 2 days               | 11/07/2023   | 11/08/2023   | Task 15                                  | Project Closure Document            |
#
# ---
#
# #### Gantt Chart (Visual Timeline)
#
# ```plaintext
# |----------------|------------|-------------|-------------|-------------|-------------|-------------|-------------|-------------|-------------|-------------|-------------|-------------|-------------|-------------|-------------|
# | 09/01          | 09/02     | 09/03      | 09/04      | 09/05      | 09/06      | 09/07      | 09/08      | 09/09      | 09/10      | 09/11      | 09/12      | 09/13      | 09/14      | 09/15      | 09/16      |
# | Kick-off       | Gathering  |             |             | Wireframes  |             |             |             | Responsive   |             |             |             |             |             |             |             |
# |                |            |             |             |             | UI Dev.    |             |             |             |             |             |             |             |             |             |
# |                |            |             |             |             |             | Navigation  |             |             |             |             |             |             |             |             |
# |                |            |             |             |             |             |             | About Us    |             |             |             |             |             |             |             |
# |                |            |             |             |             |             |             |             | Services     |             |             |             |             |             |             |
# |                |            |             |             |             |             |             |             |             | Contact Us   |             |             |             |             |             |
# |                |            |             |             |             |             |             |             |             |             | Blog        |             |             |             |             |
# |                |            |             |             |             |             |             |             |             |             |             | SEO         |             |             |             |
# |                |            |             |             |             |             |             |             |             |             |             |             | Social Media |             |             |
# |                |            |             |             |             |             |             |             |             |             |             |             |             | Testimonials |             |
# |                |            |             |             |             |             |             |             |             |             |             |             |             |             | QA          |
# |                |            |             |             |             |             |             |             |             |             |             |             |             |             | Final Adj.  |
# |                |            |             |             |             |             |             |             |             |             |             |             |             |             | Closure      |
# |----------------|------------|-------------|-------------|-------------|-------------|-------------|-------------|-------------|-------------|-------------|-------------|-------------|-------------|-------------|
# ```
#
# ---
#
# ### Conclusion
#
# This detailed task breakdown provides clarity at each stage of the website development process, ensuring that all aspects are covered and that the final product meets business objectives. With assigned team members, timelines, and dependencies outlined, this plan is set up for success. Utilizing this approach, we can ensure the project progresses smoothly and achieves its desired outcomes on time and within the agreed scope.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for Website Project
#
# #### 1. Project Kick-off
# - **Duration**: 1 day
# - **Resources**: 1 Project Manager (John Doe)
# - **Effort**: 8 hours
# - **Risks/Uncertainties**: Misunderstanding project goals or objectives from the outset can lead to scope creep later.
#
# #### 2. Requirement Gathering
# - **Duration**: 3 days
# - **Resources**: 2 Team Members (John Doe, Jane Doe)
# - **Effort**: 48 hours (24 hours each)
# - **Risks/Uncertainties**: Lack of clarity from stakeholders may hinder gathering; potential need for follow-up meetings.
#
# #### 3. Create Wireframes
# - **Duration**: 5 days
# - **Resources**: 1 Designer (Bob Smith)
# - **Effort**: 40 hours
# - **Risks/Uncertainties**: Changing requirements might necessitate rework; stakeholder approval delays.
#
# #### 4. Responsive Design
# - **Duration**: 7 days
# - **Resources**: 1 Designer (Bob Smith)
# - **Effort**: 56 hours
# - **Risks/Uncertainties**: Difficulty in achieving cross-device compatibility; reliance on timely feedback.
#
# #### 5. UI Development
# - **Duration**: 10 days
# - **Resources**: 1 Developer (Jane Doe)
# - **Effort**: 80 hours
# - **Risks/Uncertainties**: Technical limitations could arise during implementation; possible need for design adjustments.
#
# #### 6. Navigation System
# - **Duration**: 5 days
# - **Resources**: 1 Developer (Jane Doe)
# - **Effort**: 40 hours
# - **Risks/Uncertainties**: User testing may reveal design flaws; additional iterations might be necessary.
#
# #### 7. "About Us" Page
# - **Duration**: 3 days
# - **Resources**: 1 Writer/Developer (Jane Doe)
# - **Effort**: 24 hours
# - **Risks/Uncertainties**: Information accuracy relies on stakeholder input; potential for misalignment with brand voice.
#
# #### 8. "Services" Page
# - **Duration**: 4 days
# - **Resources**: 1 Writer/Developer (Jane Doe)
# - **Effort**: 32 hours
# - **Risks/Uncertainties**: May require feedback from sales/marketing; potential for scope changes as services evolve.
#
# #### 9. "Contact Us" Page
# - **Duration**: 4 days
# - **Resources**: 1 Developer (Jane Doe)
# - **Effort**: 32 hours
# - **Risks/Uncertainties**: Integration challenges with maps and forms; testing will be crucial to ensure functionality.
#
# #### 10. Blog Section
# - **Duration**: 6 days
# - **Resources**: 1 Developer (Jane Doe)
# - **Effort**: 48 hours
# - **Risks/Uncertainties**: Content management system integration might pose challenges; need for user-friendly features.
#
# #### 11. SEO Optimization
# - **Duration**: 4 days
# - **Resources**: 1 SEO Specialist (Jane Doe)
# - **Effort**: 32 hours
# - **Risks/Uncertainties**: Search engine algorithm changes may impact outcomes; ongoing optimization may be needed after launch.
#
# #### 12. Social Media Integration
# - **Duration**: 3 days
# - **Resources**: 1 Developer (Jane Doe)
# - **Effort**: 24 hours
# - **Risks/Uncertainties**: Changes in social media APIs could affect integration; testing must verify all functionalities.
#
# #### 13. Testimonials Section
# - **Duration**: 3 days
# - **Resources**: 1 Designer (Bob Smith)
# - **Effort**: 24 hours
# - **Risks/Uncertainties**: Appropriate testimonials must be collected; design may need approvals that could delay progress.
#
# #### 14. Quality Assurance (QA)
# - **Duration**: 6 days
# - **Resources**: 2 QA Testers (Alice Johnson, Tom Brown)
# - **Effort**: 96 hours (48 hours each)
# - **Risks/Uncertainties**: Potential for discovering critical defects late in the process; may require significant rework.
#
# #### 15. Final Adjustments
# - **Duration**: 3 days
# - **Resources**: 1 Developer (Jane Doe)
# - **Effort**: 24 hours
# - **Risks/Uncertainties**: May need to address significant issues from QA; timeline could shift based on findings.
#
# #### 16. Project Closure
# - **Duration**: 2 days
# - **Resources**: 1 Project Manager (John Doe)
# - **Effort**: 16 hours
# - **Risks/Uncertainties**: Stakeholder absence may delay final approvals; documentation must be thorough to avoid future disputes.
#
# ### Summary of Risks
# - **Communication Gaps**: Regular meetings and updates are essential to ensure all stakeholders are aligned.
# - **Changing Requirements**: Flexibility in timeline and budget should be considered to accommodate potential scope changes.
# - **Technical Hurdles**: Possible challenges with system integrations or performance issues should be planned for in advance.
#
# This estimation report is designed to guide the execution of the Website project efficiently, ensuring that all tasks are accounted for, resources are allocated effectively, and risks are mitigated adequately to achieve successful project delivery within the specified time and budget constraints.
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for Website Project
#
# | Task                         | Assigned Team Members         | Start Date | End Date   | Total Effort (Hours) |
# |------------------------------|-------------------------------|------------|------------|-----------------------|
# | Project Kick-off             | John Doe                      | Day 1      | Day 1      | 8                     |
# | Requirement Gathering         | John Doe, Jane Doe           | Day 2      | Day 4      | 48                    |
# | Create Wireframes            | Bob Smith                     | Day 5      | Day 9      | 40                    |
# | Responsive Design             | Bob Smith                     | Day 10     | Day 16     | 56                    |
# | UI Development               | Jane Doe                      | Day 17     | Day 26     | 80                    |
# | Navigation System            | Jane Doe                      | Day 27     | Day 31     | 40                    |
# | "About Us" Page             | Jane Doe                      | Day 32     | Day 34     | 24                    |
# | "Services" Page             | Jane Doe                      | Day 35     | Day 38     | 32                    |
# | "Contact Us" Page           | Jane Doe                      | Day 39     | Day 42     | 32                    |
# | Blog Section                 | Jane Doe                      | Day 43     | Day 48     | 48                    |
# | SEO Optimization             | Jane Doe                      | Day 49     | Day 52     | 32                    |
# | Social Media Integration      | Jane Doe                      | Day 53     | Day 55     | 24                    |
# | Testimonials Section         | Bob Smith                     | Day 56     | Day 58     | 24                    |
# | Quality Assurance (QA)      | Alice Johnson, Tom Brown      | Day 59     | Day 64     | 96                    |
# | Final Adjustments            | Jane Doe                      | Day 65     | Day 67     | 24                    |
# | Project Closure               | John Doe                      | Day 68     | Day 69     | 16                    |
#
# ### Summary Explaining Allocation Rationales
#
# 1. **Project Kick-off**: Assigned to John Doe as the project manager, who will lead this phase ensuring goals are clear.
#
# 2. **Requirement Gathering**: Includes both John Doe (Project Manager) and Jane Doe (Software Engineer) to gather technical requirements and align them with project goals effectively.
#
# 3. **Create Wireframes**: Bob Smith, being the sole designer, is tasked with creating the wireframes over 5 days, focused solely on design aspects.
#
# 4. **Responsive Design**: Bob Smith continues his role, allowing a single point of contact for design-related issues while ensuring continuity.
#
# 5. **UI Development**: Given Jane Doe's expertise as a software engineer, she takes on UI development for her skills in translating designs into functional code.
#
# 6. **Navigation System**: Assigned to Jane Doe again, maintaining her role in site navigation that directly follows UI completion.
#
# 7. **"About Us" Page**: Jane Doe is further leveraged, allowing her to develop content that supports brand identity.
#
# 8. **"Services" Page**: Continues with Jane Doe to maintain momentum, focusing again on the conveying of service details.
#
# 9. **"Contact Us" Page**: Jane Doe’s familiarity with user input forms makes her the ideal choice for this task, which supports UI integrity.
#
# 10. **Blog Section**: Allocating Jane Doe ensures consistency in coding practices, facilitating easier updates post-implementation.
#
# 11. **SEO Optimization**: Jane remains the most beneficial choice for this task due to her development experience, ensuring that code meets optimization standards.
#
# 12. **Social Media Integration**: Assigned to Jane for consistency in integration, taking advantage of her prior knowledge of the website’s structure.
#
# 13. **Testimonials Section**: Bob Smith takes on this less intensive task post his design responsibilities, ensuring the visual appeal of testimonials is maintained.
#
# 14. **Quality Assurance (QA)**: Harry and Tom are assigned to perform QA, ensuring an ample workload balance while allowing for comprehensive testing.
#
# 15. **Final Adjustments**: Jane is tasked as the developer to refine aspects post-QA feedback implementation.
#
# 16. **Project Closure**: Finally, John Doe leads the closure phase to ensure proper project wrap-up, documentation, and stakeholder approvals.
#
# The allocation strategy focuses on balancing member workload, reinforcing continuity within tasks, maximizing utilization of individual skill sets, and ensuring efficiency across the project's timeline. By segmenting tasks in this manner, we reduce potential risks associated with communication gaps, changing requirements, and technical hurdles throughout the project lifecycle. This structure aims to lead to a successful project delivery within established time frames and budgets.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0032
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         21405          12990               8415                    9

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Project Kick-off',
#    'estimated_time_hours': 8.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Requirement Gathering',
#    'estimated_time_hours': 48.0,
#    'required_resources': ['John Doe', 'Jane Doe']},
#   {'task_name': 'Create Wireframes',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Responsive Design',
#    'estimated_time_hours': 56.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'UI Development',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Navigation System',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'About Us Page',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Services Page',
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Contact Us Page',
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Blog Section',
#    'estimated_time_hours': 48.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'SEO Optimization',
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Social Media Integration',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Testimonials Section',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Quality Assurance (QA)',
#    'estimated_time_hours': 96.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']},
#   {'task_name': 'Final Adjustments',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Project Closure',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['John Doe']}],
#  'milestones': [{'milestone_name': 'Project Initiation',
#    'tasks': ['Project Kick-off', 'Requirement Gathering']},
#   {'milestone_name': 'Design Phase',
#    'tasks': ['Create Wireframes', 'Responsive Design']},
#   {'milestone_name': 'Development Phase',
#    'tasks': ['UI Development',
#     'Navigation System',
#     'About Us Page',
#     'Services Page',
#     'Contact Us Page',
#     'Blog Section']},
#   {'milestone_name': 'Testing Phase', 'tasks': ['Quality Assurance (QA)']},
#   {'milestone_name': 'Finalization Phase',
#    'tasks': ['Final Adjustments', 'Project Closure']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_c43d9 th {
#   font-size: 120%;
# }
# #T_c43d9  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_c43d9" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c43d9_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_c43d9_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_c43d9_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c43d9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c43d9_row0_col0" class="data row0 col0" >Project Kick-off</td>
#       <td id="T_c43d9_row0_col1" class="data row0 col1" >8.000000</td>
#       <td id="T_c43d9_row0_col2" class="data row0 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_c43d9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c43d9_row1_col0" class="data row1 col0" >Requirement Gathering</td>
#       <td id="T_c43d9_row1_col1" class="data row1 col1" >48.000000</td>
#       <td id="T_c43d9_row1_col2" class="data row1 col2" >['John Doe', 'Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_c43d9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c43d9_row2_col0" class="data row2 col0" >Create Wireframes</td>
#       <td id="T_c43d9_row2_col1" class="data row2 col1" >40.000000</td>
#       <td id="T_c43d9_row2_col2" class="data row2 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_c43d9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c43d9_row3_col0" class="data row3 col0" >Responsive Design</td>
#       <td id="T_c43d9_row3_col1" class="data row3 col1" >56.000000</td>
#       <td id="T_c43d9_row3_col2" class="data row3 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_c43d9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c43d9_row4_col0" class="data row4 col0" >UI Development</td>
#       <td id="T_c43d9_row4_col1" class="data row4 col1" >80.000000</td>
#       <td id="T_c43d9_row4_col2" class="data row4 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_c43d9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c43d9_row5_col0" class="data row5 col0" >Navigation System</td>
#       <td id="T_c43d9_row5_col1" class="data row5 col1" >40.000000</td>
#       <td id="T_c43d9_row5_col2" class="data row5 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_c43d9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c43d9_row6_col0" class="data row6 col0" >About Us Page</td>
#       <td id="T_c43d9_row6_col1" class="data row6 col1" >24.000000</td>
#       <td id="T_c43d9_row6_col2" class="data row6 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_c43d9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c43d9_row7_col0" class="data row7 col0" >Services Page</td>
#       <td id="T_c43d9_row7_col1" class="data row7 col1" >32.000000</td>
#       <td id="T_c43d9_row7_col2" class="data row7 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_c43d9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c43d9_row8_col0" class="data row8 col0" >Contact Us Page</td>
#       <td id="T_c43d9_row8_col1" class="data row8 col1" >32.000000</td>
#       <td id="T_c43d9_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_c43d9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c43d9_row9_col0" class="data row9 col0" >Blog Section</td>
#       <td id="T_c43d9_row9_col1" class="data row9 col1" >48.000000</td>
#       <td id="T_c43d9_row9_col2" class="data row9 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_c43d9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c43d9_row10_col0" class="data row10 col0" >SEO Optimization</td>
#       <td id="T_c43d9_row10_col1" class="data row10 col1" >32.000000</td>
#       <td id="T_c43d9_row10_col2" class="data row10 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_c43d9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c43d9_row11_col0" class="data row11 col0" >Social Media Integration</td>
#       <td id="T_c43d9_row11_col1" class="data row11 col1" >24.000000</td>
#       <td id="T_c43d9_row11_col2" class="data row11 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_c43d9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c43d9_row12_col0" class="data row12 col0" >Testimonials Section</td>
#       <td id="T_c43d9_row12_col1" class="data row12 col1" >24.000000</td>
#       <td id="T_c43d9_row12_col2" class="data row12 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_c43d9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c43d9_row13_col0" class="data row13 col0" >Quality Assurance (QA)</td>
#       <td id="T_c43d9_row13_col1" class="data row13 col1" >96.000000</td>
#       <td id="T_c43d9_row13_col2" class="data row13 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_c43d9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c43d9_row14_col0" class="data row14 col0" >Final Adjustments</td>
#       <td id="T_c43d9_row14_col1" class="data row14 col1" >24.000000</td>
#       <td id="T_c43d9_row14_col2" class="data row14 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_c43d9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c43d9_row15_col0" class="data row15 col0" >Project Closure</td>
#       <td id="T_c43d9_row15_col1" class="data row15 col1" >16.000000</td>
#       <td id="T_c43d9_row15_col2" class="data row15 col2" >['John Doe']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_98073 th {
#   font-size: 120%;
# }
# #T_98073  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_98073" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98073_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_98073_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98073_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98073_row0_col0" class="data row0 col0" >Project Initiation</td>
#       <td id="T_98073_row0_col1" class="data row0 col1" >['Project Kick-off', 'Requirement Gathering']</td>
#     </tr>
#     <tr>
#       <th id="T_98073_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_98073_row1_col0" class="data row1 col0" >Design Phase</td>
#       <td id="T_98073_row1_col1" class="data row1 col1" >['Create Wireframes', 'Responsive Design']</td>
#     </tr>
#     <tr>
#       <th id="T_98073_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_98073_row2_col0" class="data row2 col0" >Development Phase</td>
#       <td id="T_98073_row2_col1" class="data row2 col1" >['UI Development', 'Navigation System', 'About Us Page', 'Services Page', 'Contact Us Page', 'Blog Section']</td>
#     </tr>
#     <tr>
#       <th id="T_98073_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_98073_row3_col0" class="data row3 col0" >Testing Phase</td>
#       <td id="T_98073_row3_col1" class="data row3 col1" >['Quality Assurance (QA)']</td>
#     </tr>
#     <tr>
#       <th id="T_98073_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_98073_row4_col0" class="data row4 col0" >Finalization Phase</td>
#       <td id="T_98073_row4_col1" class="data row4 col1" >['Final Adjustments', 'Project Closure']</td>
#     </tr>
#   </tbody>
# </table>
